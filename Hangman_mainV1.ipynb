# %% [markdown]
# # HANGMAN GAME

# %%
# hello

# %%
# what

# %%
from random_word import RandomWords

r = RandomWords()

print(r.get_random_word())
# Out:
# wagers

# %%
r.get_random_word()
# Out:
# 'cathern'

# %%
generated_word = []

def random_word_maker():
    generated_word.append(r.get_random_word())

# %%
random_word_maker()

# %%
generated_word
# Out:
# ['chirotonsor']

# %%
r.get_random_word()
# Out:
# 'expropriation'

# %% [markdown]
# # Hangman
# Description of Game:
# - Objective
# - Rules etc.

# %% [markdown]
# ## Functions
# - code
# - local imports
# - test

# %% [markdown]
# ### random_word_maker
# random word generator

# %%
#!pip install random-word

from random_word import RandomWords

r = RandomWords()

print(r.get_random_word())
# Out:
# pachytylus

# %%
def random_word_maker():
    generated_word.append(r.get_random_word())

# %%
random_word_maker()

# %%
generated_word
# Out:
# ['popularizer']

# %% [markdown]
# ### letter count of random word

# %%
def random_word_length(generated_word):
    num_letters = len(generated_word[0])
    blank_word = ["_ "] * num_letters
    return blank_word

# %%
random_word_length(generated_word)
# Out:
# ['_ ', '_ ', '_ ', '_ ', '_ ', '_ ', '_ ', '_ ', '_ ', '_ ', '_ ']

# %%
unknown_word = random_word_length(generated_word)
unknown_word
# Out:
# ['_ ', '_ ', '_ ', '_ ', '_ ', '_ ', '_ ', '_ ', '_ ', '_ ', '_ ']

# %% [markdown]
# ### letter_choice

# %%
#letter choice
#guessed_letter = []
def letter_choice():
    while True:
        guess = input("guess a letter a-z: ").lower()
        if len(guess) >=2 :
            print("1 character at a time please!") 
        elif not guess.isalpha():
            print("please guess a *LETTER*")
        else:
            return(guess)

guessed_letter = letter_choice()
print(guessed_letter)


# problem it stops when
# Out:
# d

# %% [markdown]
# ### letter_check

# %% [markdown]
# Description
# Edit
# ##if letter_choice is right then populate all occurances of that letter
#
# Take latest letter_choice and see if it’s in the unknown_word
#
# if yes -  Return True
#
# if no - Return False
#
#
#
# easier to check if all letters are converted into elements in a list e.g. [“a”,”x”,”e”]
#
# we want a list because it is mutable

# %%
# word here refers to random word
#randomword = "apple"
#display = ["_"] * len(randomword)
#guessed_letter = "p"

#for index, letter in enumerate(randomword):
#    if letter == guessed_letter:
#        display[index] = guessed_letter

#print(display)
#pass

# when you choose a letter and it is wrong
# Out:
# ['_', 'p', 'p', '_', '_']

# %%
# list(enumerate(randomword))
# Out:
# [(0, 'a'), (1, 'p'), (2, 'p'), (3, 'l'), (4, 'e')]

# %%
# LETTER CHECKER Done
#randomword = "apple"

def letter_check ():
    #list(enumerate(randomword))
    for letter in generated_word[0]:
        if guessed_letter == letter:
            return True
        else:
            return False
        
letter_check = letter_check()
letter_check
# Out:
# False

# %%
generated_word
# Out:
# ['popularizer']

# %%
x = ["apple"]
y = ["x"]

# %%
if y in x:
    print("yes")
else: print("no")
# Out:
# yes

# %%
for i in x:
    if y[0] in x[0]:
        print("yes")
    else: print("no")
# Out:
# yes

# %%
if y[0] in x[0]:
    print("yes")
else:
    print("no")
# Out:
# no

# %% [markdown]
# ### wrong_letter_count

# %%
def wrong_letter_count():
    if letter_check == False:
        wrong_guess_count += 1

# %%
# first attempt
wrong_guesses = 0
def wrong_letter_count():
    for letter in randomword:
        if letter != guessed_word:
            wrong_guesses + 1
        if wrong_guesses == 5:
            print ("You loose!")

# %% [markdown]
# ### display_hangman

# %% [markdown]
# ### update_guess

# %%
guessed_letter
# Out:
# 'd'

# %%
randomword
# Out:
# 'apple'

# %%
list(enumerate(generated_word[0]))
# Out:
# [(0, 'p'),
#  (1, 'o'),
#  (2, 'p'),
#  (3, 'u'),
#  (4, 'l'),
#  (5, 'a'),
#  (6, 'r'),
#  (7, 'i'),
#  (8, 'z'),
#  (9, 'e'),
#  (10, 'r')]

# %%
def update_guess():
    if letter_check == True:
        # look at the generated word and take the matching letters and populate the list of blank spaces
		if guessed_letter in generated_word[0]:
                        #find the index position of that letter and change unknown to that
                        #list(enumerate(generated_word[0]))
                        for index, letter in list(enumerate(generated_word[0]):
                                                  if guessed_letter == letter
                                                  

    else:


# make a for loop to create a new list and rename it under the same variable or a new variable ?

# %% [markdown]
# ### lose_check

# %% [markdown]
# ### win_check

# %% [markdown]
# ### replay()

# %% [markdown]
# ### Play Game

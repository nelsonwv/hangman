# %% [markdown]
# # Hangman
# Description of Game:
# - Objective
# - Rules etc.

# %% [markdown]
# ## Functions
# - code
# - local imports
# - test

# %% [markdown]
# ### random_word_maker
# random word generator

# %% [markdown]
# ### letter count of random word

# %% [markdown]
# ### letter_choice

# %% [markdown]
# ### letter_check

# %% [markdown]
# ### wrong_letter_count

# %% [markdown]
# ### display_hangman

# %% [markdown]
# ### update_guess

# %% [markdown]
# ### lose_check

# %% [markdown]
# ### win_check

# %% [markdown]
# ### replay()

# %% [markdown]
# ### Play Game
